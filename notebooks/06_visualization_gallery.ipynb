# %% [markdown]
# # QATNE Visualization Gallery
#
# Comprehensive visualizations for QATNE algorithm analysis, now using the built-in `qatne.utils.visualization` module.

# %%
# Colab setup
# !pip install -q git+https://github.com/Tommaso-R-Marena/qatne.git
# !pip install -q plotly networkx

import numpy as np
import matplotlib.pyplot as plt
from qatne.utils import visualization
from qatne.core.tensor_network import TensorNetwork
from qiskit import QuantumCircuit

# %% [markdown]
# ## 1. Energy Landscape 3D Visualization
#
# Interactive 3D visualization of the parameter energy landscape using Plotly.

# %%
# Create synthetic energy landscape
theta1 = np.linspace(0, 2*np.pi, 50)
theta2 = np.linspace(0, 2*np.pi, 50)
Theta1, Theta2 = np.meshgrid(theta1, theta2)
Energy = (np.cos(Theta1) + np.cos(Theta2) + 0.5*np.sin(2*Theta1) + 0.3*np.sin(2*Theta2) + 2)

fig = visualization.plot_energy_landscape(theta1, theta2, Energy)
fig.show()

# %% [markdown]
# ## 2. Tensor Network Structure Diagram
#
# Visualize the adaptive tensor network graph where edge widths reflect bond dimensions.

# %%
# Create and adapt a mock tensor network
tn = TensorNetwork(num_sites=8, bond_dim=4)
tn.increase_bond_dim(1)  # chi=8
tn.increase_bond_dim(1)  # chi=16
tn.increase_bond_dim(4)  # chi=8

visualization.plot_tensor_network_structure(tn)
plt.show()

# %% [markdown]
# ## 3. Quantum Circuit Evolution
#
# Display the adaptation of the quantum circuit ansatz across optimization stages.

# %%
circs = []
for depth in [1, 2, 3]:
    qc = QuantumCircuit(4)
    for _ in range(depth):
        qc.ry(0.5, range(4))
        qc.cx(0, 1); qc.cx(2, 3)
    circs.append(qc)

visualization.plot_circuit_evolution(circs, titles=['Initial', 'Intermediate', 'Final'])
plt.show()

# %% [markdown]
# ## 4. Statistical Convergence Analysis
#
# Comprehensive analysis of multiple trials including distributions, Q-Q plots, and box plots.

# %%
np.random.seed(42)
exact = -1.137
trials = exact + np.random.normal(0, 0.002, 30)

visualization.plot_statistical_analysis(trials, exact)
plt.show()

# %% [markdown]
# ## 5. Bond Dimension Heatmap
#
# Track how bond dimensions evolve throughout the entire optimization process.

# %%
# Simulate bond dimension history
history = np.full((7, 100), 4.0)
history[3, 50:] = 8
history[3, 80:] = 16
history[4, 60:] = 8

visualization.plot_bond_dimension_evolution(history)
plt.show()

# %% [markdown]
# ## 6. Interactive Optimization Dashboard
#
# Real-time tracking of energy, gradients, and parameters in a single interactive view.

# %%
iters = np.arange(100)
energy = -1.137 + 0.5 * np.exp(-iters/20)
grads = 0.5 * np.exp(-iters/15)
avg_chi = 4 + 12 * (1 - np.exp(-iters/40))
traj = np.column_stack([np.sin(iters/10), np.cos(iters/10)])

fig = visualization.create_interactive_dashboard(iters, energy, grads, avg_chi, traj, exact_energy=-1.137)
fig.show()
